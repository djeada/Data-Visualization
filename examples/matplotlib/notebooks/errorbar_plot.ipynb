# %%
import matplotlib.pyplot as plt
import numpy as np

n = 30
error = 0.2

x = np.linspace(0, 10, n)
y = np.sin(x) + np.random.randn(n)*error
plt.errorbar(x, y, yerr=error, fmt='.k', capsize=5, markeredgewidth=1)
plt.show()
