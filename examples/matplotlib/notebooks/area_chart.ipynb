# %%
import numpy as np

x = np.arange(1, 6)
y1 = np.array([1, 2, 3, 4, 5])
y2 = np.array([2, 3, 4, 5, 6])
y3 = np.array([3, 4, 5, 6, 7])

fig, ax = plt.subplots()

ax.fill_between(x, 0, y1, alpha=0.1)
ax.fill_between(x, 0, y2, alpha=0.1)
ax.fill_between(x, 0, y3, alpha=0.1)

plt.title('Area Chart')
plt.xlabel('Time')
plt.ylabel('Value')

plt.show()
